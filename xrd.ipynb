# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.analysis.diffraction.xrd import XRDCalculator
with MPRester("8dT4ZwJiqOtEkr83gIsD") as m:

    # Structure for material id
    structure = m.get_structure_by_material_id("mp-867339")
    
xrd = XRDCalculator(wavelength='CuKa')
pattern = xrd.get_pattern(structure)

# %%
pic = ["First pic " , "Second pic ","Tird pic "]
for i in range(3):
    print(pic[i])
    print("Angle 2\u0398 = ", pattern.x[i], "°")
    print("Intensity = ", pattern.y[i], "%")
    print("Indices h k l : ", pattern.hkls[i])
    print("\n")
# Out:
# First pic
# Angle 2Θ =  17.220485026806816 °
# Intensity =  6.4437457520634105 %
# Indices h k l :  [{'hkl': (1, 1, 1), 'multiplicity': 2}, {'hkl': (1, 0, 0), 'multiplicity': 6}]
#
#
# Second pic
# Angle 2Θ =  19.90976506012852 °
# Intensity =  41.333689755872946 %
# Indices h k l :  [{'hkl': (1, 1, 0), 'multiplicity': 6}]
#
#
# Tird pic
# Angle 2Θ =  28.302072617470973 °
# Intensity =  100.0 %
# Indices h k l :  [{'hkl': (2, 1, 1), 'multiplicity': 6}, {'hkl': (1, 0, -1), 'multiplicity': 6}]

# %%
xrd.get_plot(structure, two_theta_range=(0,30))
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.9/site-packages/matplotlib/pyplot.py'>
